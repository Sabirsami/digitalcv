# %% [markdown]
# <a href="https://colab.research.google.com/github/Sabirsami/digitalcv/blob/master/ChatbotAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai

# %%
from google.colab import userdata
GOOGLE_API_KEY=userdata.get("GOOGLE_API_KEY")
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel("gemini-2.0-flash-exp")
response=model.generate_content("Give me python code to start the list")
print(response.text)

# %%
squair=[x**2 for x in range(1,6)]
print(squair)

# %%
even_num=[num for num in range(10) if num%2==0]
print(even_num)

# %%
# !pip install langchain langchain-google-genai
import langchain_google_genai as genai
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model:ChatGoogleGenerativeAI=ChatGoogleGenerativeAI(
model="gemini-2.0-flash-exp",
api_key=GOOGLE_API_KEY,
)
response1=model.invoke("who is founder of New pakistan")
print(f"""{response1.content}""")
